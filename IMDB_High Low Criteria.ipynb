# %%
import pandas as pd
import numpy as np

# %%
imdb = pd.read_csv("IMDB.csv", encoding = "Latin1")
imdb.head(5)
# Out:
#    movie_ID                               movie_title  duration  color  \
# 0         1                                    Avatar       178      1
# 1         2  Pirates of the Caribbean: At World's End       169      1
# 2         3                     The Dark Knight Rises       164      1
# 3         4                              Spider-Man 3       156      1
# 4         5        Batman v Superman: Dawn of Justice       183      1
#
#    title_year country language content_rating  budget_USD  gross_USD  \
# 0        2009     USA  English          PG-13   237000000  760505847
# 1        2007     USA  English          PG-13   300000000  309404152
# 2        2012     USA  English          PG-13   250000000  448130642
# 3        2007     USA  English          PG-13   258000000  336530303
# 4        2016     USA  English          PG-13   250000000  330249062
#
#        ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0      ...                       1                     855
# ...

# %%
imdb.isnull().sum()
# Out:
# movie_ID                     0
# movie_title                  0
# duration                     0
# color                        0
# title_year                   0
# country                      0
# language                     0
# content_rating               0
# budget_USD                   0
# gross_USD                    0
# net_USD                      0
# profitable                   0
# director_name                0
# director_top20?              0
# director_facebook?           0
# director_facebook_likes      0
# actor_1_name                 0
# actor_top20?                 0
# actor_1_facebook?            0
# actor_1_facebook_likes       0
# actor_2_name                 0
# actor_top20?.1               0
# actor_2_facebook?            0
# actor_2_facebook_likes       0
# actor_3_name                 0
# actor_top20?.2               0
# actor_3_facebook?            0
# actor_3_facebook_likes       0
# cast_total_facebook_likes    0
# movie_facebook?              0
# ...

# %%
imdb = imdb.drop_duplicates()

# %%
imdb.shape
# Out:
# (3781, 36)

# %%
imdb[["duration", "gross_USD"]].describe()
# Out:
#           duration     gross_USD
# count  3781.000000  3.781000e+03
# mean    109.950278  5.182002e+07
# std      22.299267  7.003776e+07
# min      37.000000  1.620000e+02
# 25%      95.000000  7.605668e+06
# 50%     106.000000  2.896520e+07
# 75%     120.000000  6.600997e+07
# max     325.000000  7.605058e+08

# %%
imdb["color"].value_counts()
# Out:
# 1    3657
# 0     124
# Name: color, dtype: int64

# %%
imdb["content_rating"].value_counts()
# Out:
# R            1715
# PG-13        1311
# PG            568
# G              88
# Not Rated      39
# Unrated        24
# Approved       14
# X              10
# NC-17           6
# Passed          3
# M               2
# GP              1
# Name: content_rating, dtype: int64

# %%
imdb[imdb["color"] == 0]
# Out:
#       movie_ID                            movie_title  duration  color  \
# 48          49                           Pearl Harbor       184      0
# 72          73                        Die Another Day       133      0
# 121        122                            The Aviator       170      0
# 138        139                                 Eragon       104      0
# 186        187                             Seabiscuit       140      0
# 354        355                         The Great Raid       132      0
# 361        362                           Forrest Gump       142      0
# 371        372                      Kill Bill: Vol. 1       111      0
# 372        373                      Kill Bill: Vol. 2       137      0
# 380        381               The Phantom of the Opera       143      0
# 387        388                     All the King's Men       128      0
# 420        421                              Assassins       132      0
# ...

# %%
imdb["score_group"]=['High' if x >= 7.5 else 'Low' for x in imdb['imdb_score']] 
imdb
# Out:
#       movie_ID                                movie_title  duration  color  \
# 0            1                                     Avatar       178      1
# 1            2   Pirates of the Caribbean: At World's End       169      1
# 2            3                      The Dark Knight Rises       164      1
# 3            4                               Spider-Man 3       156      1
# 4            5         Batman v Superman: Dawn of Justice       183      1
# 5            6                           Superman Returns       169      1
# 6            7                               Man of Steel       143      1
# 7            8  The Hobbit: The Battle of the Five Armies       164      1
# 8            9                     The Amazing Spider-Man       153      1
# 9           10                                 Robin Hood       156      1
# 10          11                                  King Kong       201      1
# ...

# %% [markdown]
# movie_all_count = imdb[imdb['score_group']=="High"]
# sort_all = movie_all_count.sort_values("imdb_score", ascending=False)
# sort_all.head()

# %%
movie_all_count = imdb[imdb['score_group']=="Low"]
sort_all = movie_all_count.sort_values("imdb_score", ascending=False)
sort_all.head(5)
# Out:
#       movie_ID                 movie_title  duration  color  title_year  \
# 1485      1486              Blue Valentine       112      1        2010
# 2795      2796          My Sister's Keeper       109      1        2009
# 564        565                 Poltergeist       120      1        1982
# 1454      1455     The Squid and the Whale        88      1        2005
# 2860      2861  The Baader Meinhof Complex       184      1        2008
#
#       country language content_rating  budget_USD  gross_USD     ...       \
# 1485      USA  English              R     3500000    9701559     ...
# 2795      USA  English          PG-13    30000000   49185998     ...
# 564       USA  English             PG    10700000   76600000     ...
# 1454      USA  English              R     1500000    7362100     ...
# 2860  Germany   German              R    20000000     476270     ...
#
#       actor_3_facebook_likes  cast_total_facebook_likes movie_facebook?  \
# ...
