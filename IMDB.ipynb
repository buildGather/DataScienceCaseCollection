# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  ### 1. How many rows and columns reflected on dataset file IMDB-database-update.csv?

# %%
imdb = pd.read_csv("IMDB.csv", encoding = "ISO-8859-1")
imdb.head(5)
# Out:
#    movie_ID                               movie_title  duration  color  \
# 0         1                                    Avatar       178      1
# 1         2  Pirates of the Caribbean: At World's End       169      1
# 2         3                     The Dark Knight Rises       164      1
# 3         4                              Spider-Man 3       156      1
# 4         5        Batman v Superman: Dawn of Justice       183      1
#
#    title_year country language content_rating  budget_USD  gross_USD  \
# 0        2009     USA  English          PG-13   237000000  760505847
# 1        2007     USA  English          PG-13   300000000  309404152
# 2        2012     USA  English          PG-13   250000000  448130642
# 3        2007     USA  English          PG-13   258000000  336530303
# 4        2016     USA  English          PG-13   250000000  330249062
#
#        ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0      ...                       1                     855
# ...

# %%
imdb.describe()
# Out:
#           movie_ID     duration        color   title_year    budget_USD  \
# count  3781.000000  3781.000000  3781.000000  3781.000000  3.781000e+03
# mean   1891.000000   109.950278     0.967204  2003.081989  4.572770e+07
# std    1091.625012    22.299267     0.178125     9.837954  2.252895e+08
# min       1.000000    37.000000     0.000000  1927.000000  2.180000e+02
# 25%     946.000000    95.000000     1.000000  1999.000000  1.000000e+07
# 50%    1891.000000   106.000000     1.000000  2005.000000  2.500000e+07
# 75%    2836.000000   120.000000     1.000000  2010.000000  5.000000e+07
# max    3781.000000   325.000000     1.000000  2016.000000  1.221550e+10
#
#           gross_USD       net_USD   profitable  director_facebook?  \
# count  3.781000e+03  3.781000e+03  3781.000000         3781.000000
# mean   5.182002e+07  6.092318e+06     0.531870            0.828352
# std    7.003776e+07  2.291199e+08     0.499049            0.377124
# ...

# %%
imdb.shape
# Out:
# (3781, 36)

# %%
imdb.columns
# Out:
# Index(['movie_ID', 'movie_title', 'duration', 'color', 'title_year', 'country',
#        'language', 'content_rating', 'budget_USD', 'gross_USD', 'net_USD',
#        'profitable', 'director_name', 'director_top20?', 'director_facebook?',
#        'director_facebook_likes', 'actor_1_name', 'actor_top20?',
#        'actor_1_facebook?', 'actor_1_facebook_likes', 'actor_2_name',
#        'actor_top20?.1', 'actor_2_facebook?', 'actor_2_facebook_likes',
#        'actor_3_name', 'actor_top20?.2', 'actor_3_facebook?',
#        'actor_3_facebook_likes', 'cast_total_facebook_likes',
#        'movie_facebook?', 'movie_facebook_likes;', 'facenumber_in_poster',
#        'num_voted_users', 'num_user_for_reviews', 'imdb_score',
#        'imdb_top_250'],
#       dtype='object')

# %% [markdown]
# ### 2. What are the top 3 movies with highest nett profit in 2013?

# %%
movie13 = imdb[imdb.title_year == 2013]
net_sort = movie13.sort_values("net_USD", ascending=False)
net_sort.head(3)
# Out:
#       movie_ID                      movie_title  duration  color  title_year  \
# 1614      1615  The Hunger Games: Catching Fire       146      1        2013
# 236        237                  Despicable Me 2        98      1        2013
# 57          58                           Frozen       102      1        2013
#
#      country language content_rating  budget_USD  gross_USD      ...       \
# 1614     USA  English          PG-13   130000000  424645577      ...
# 236      USA  English             PG    76000000  368049635      ...
# 57       USA  English             PG   150000000  400736600      ...
#
#       actor_3_facebook?  actor_3_facebook_likes cast_total_facebook_likes  \
# 1614                  1                     523                     49355
# 236                   1                    1000                     11905
# 57                    1                     490                      2582
#
#      movie_facebook?  movie_facebook_likes;  facenumber_in_poster  \
# ...

# %% [markdown]
# ### 3. What are the top 3 movies with highest gross profit in 2009?

# %%
movie09 = imdb[imdb.title_year == 2009]
gross09 = movie09.sort_values('gross_USD', ascending=False)
gross09.head(3)
# Out:
#       movie_ID                             movie_title  duration  color  \
# 0            1                                  Avatar       178      1
# 19          20     Transformers: Revenge of the Fallen       150      1
# 3094      3095  Harry Potter and the Half-Blood Prince       153      1
#
#       title_year country language content_rating  budget_USD  gross_USD  \
# 0           2009     USA  English          PG-13   237000000  760505847
# 19          2009     USA  English          PG-13   200000000  402076689
# 3094        2009      UK  English             PG   250000000  301956980
#
#           ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0         ...                       1                     855
# 19        ...                       1                     464
# 3094      ...                       1                   10000
#
#      cast_total_facebook_likes movie_facebook?  movie_facebook_likes;  \
# ...

# %% [markdown]
# ### 4. How many non-english movies are in the dataset?

# %%
non_english = imdb[imdb.language != 'English']
#total = non_english['movie_ID'].count()
print ('Non-English movies in the dataset are',len(non_english))
# Out:
# Non-English movies in the dataset are 153

# %% [markdown]
# ### 5. What are top 3 languages in the dataset aside English (based on number of movies)?

# %%
#movie_country = imdb[imdb.country != 'English']
#net_sort = movie_country.sort_values('net_USD')
#net_sort.head(3)

non_english1 = imdb[imdb.language != 'English']
grouping = non_english1.groupby('language')
total = grouping['movie_ID'].count()
#print ('Non-English movies in the dataset are',total)
non_sort = total.sort_values(ascending = False)
non_sort.head(3)
# Out:
# language
# French      33
# Spanish     23
# Mandarin    14
# Name: movie_ID, dtype: int64

# %% [markdown]
# ### 6. What are the top 3 countries with the highest nett profit in all dataset times?

# %%
#movie_all = imdb.loc[(imdb.title_year >= 1927) & (imdb.title_year <= 2016)]
#net_all = movie_all.sort_values('net_USD')
#net_all.head(3)

movie_all = imdb.groupby('country')
movie_all_count = movie_all['net_USD'].sum()
sort_all = movie_all_count.sort_values(ascending=False)
sort_all.head(3)
# Out:
# country
# USA          52003933174
# UK            1531614524
# Australia      252571616
# Name: net_USD, dtype: int64

# %% [markdown]
# ### 7. What are the average budget of all movies in dataset in 2013?

# %%
avg13 = imdb[(imdb.title_year == 2013)]
avg131 = avg13.budget_USD.sum()

average  = avg131 / len(avg13)
average
# Out:
# 51069610.77439024

# %% [markdown]
# ### 8. What are the average budget of all movies in dataset in 2014?

# %%
avg14 = imdb[(imdb.title_year == 2014)]
avg141 = avg14.budget_USD.sum()

average1  = avg141 / len(avg14)
average1
# Out:
# 49919006.62251656

# %% [markdown]
# ### 9. Which one is higher, average budget of all movies in dataset in 2014 or 2013?

# %%
hasil = max(average, average1, key=lambda x:int(x))
print('rata-rata tertinggi diperoleh pada angka', hasil)
# Out:
# rata-rata tertinggi diperoleh pada angka 51069610.77439024

# %% [markdown]
# ### 10. What movie that resulted highest nett profit of all dataset times? How much did the movie make?

# %%
movie_all = imdb.loc[(imdb.title_year >= 1927) & (imdb.title_year <= 2016)]
net_all = movie_all.sort_values('net_USD', ascending = False)
net_all.head(3)
# Out:
#     movie_ID     movie_title  duration  color  title_year country language  \
# 0          1          Avatar       178      1        2009     USA  English
# 14        15  Jurassic World       124      1        2015     USA  English
# 11        12         Titanic       194      1        1997     USA  English
#
#    content_rating  budget_USD  gross_USD      ...       actor_3_facebook?  \
# 0           PG-13   237000000  760505847      ...                       1
# 14          PG-13   150000000  652177271      ...                       1
# 11          PG-13   200000000  658672302      ...                       1
#
#     actor_3_facebook_likes cast_total_facebook_likes movie_facebook?  \
# 0                      855                      4834               1
# 14                    1000                      8458               1
# 11                     794                     45223               1
#
#     movie_facebook_likes;  facenumber_in_poster num_voted_users  \
# ...

# %% [markdown]
# ### 10.1 Cara lain untuk menentukan "What movie that resulted highest nett profit of all dataset times? How much did the movie make?"

# %%
maxres = max(imdb.net_USD)
maxres
# Out:
# 523505847

# %%
imdb[(imdb['net_USD'] == 523505847)]
# Out:
#    movie_ID movie_title  duration  color  title_year country language  \
# 0         1      Avatar       178      1        2009     USA  English
#
#   content_rating  budget_USD  gross_USD      ...       actor_3_facebook?  \
# 0          PG-13   237000000  760505847      ...                       1
#
#    actor_3_facebook_likes cast_total_facebook_likes movie_facebook?  \
# 0                     855                      4834               1
#
#    movie_facebook_likes;  facenumber_in_poster num_voted_users  \
# 0                  33000                     0          886204
#
#    num_user_for_reviews  imdb_score  imdb_top_250
# 0                  3054         7.9             0
#
# [1 rows x 36 columns]
